# %%
import pandas as pd

# %%
cands = ["cand/%d.csv" % i for i in range(3)]
vals = []
for c in cands:
    vals.append(pd.read_csv(c, header=0, index_col=0))
vals
# Out:
# [           y
#  id
#  0   0.038904
#  1   0.105160
#  2   0.696531
#  3   0.611419
#  4   0.790877
#  5   0.390454
#  6   0.735469
#  7   0.802104
#  8   0.734064
#  9   0.691463
#  10  0.652899
#  11  0.179796
#  12  0.676871
#  13  0.293466
#  14  0.200246
#  15  0.957683
#  16  0.317516
#  17  0.809090
#  18  0.683775
#  19  0.370937
#  20  0.567366
#  21  0.842917
#  22  0.312582
#  23  0.572112
#  24  0.851996
#  25  0.853616
#  26  0.480970
#  27  0.975691
#  28  0.396036
#  29  0.810298
#  ..       ...
#  39  0.199508
#  40  0.589183
#  41  0.311205
#  42  0.251529
#  43  0.852824
#  44  0.310850
#  45  0.785570
#  46  0.233773
#  47  0.112472
#  48  0.901731
#  49  0.851924
#  50  0.966904
#  51  0.748667
#  52  0.187793
#  53  0.462587
#  54  0.592035
#  55  0.371384
#  56  0.691453
#  57  0.899793
#  58  0.912048
#  59  0.832345
#  60  0.093753
#  61  0.426339
#  62  0.758000
#  63  0.734446
#  64  0.801291
#  65  0.488123
#  66  0.719842
#  67  0.663807
#  68  0.561299
#
# ...

# %%
sol = sum(vals)/len(cands)

# %%
with open("avg.csv", 'w') as csv:
    sol.to_csv(csv)
